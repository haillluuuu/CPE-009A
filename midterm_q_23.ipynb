# %% [markdown]
# <a href="https://colab.research.google.com/github/haillluuuu/CPE-009A/blob/main/midterm_q_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i = 0
val = "*"

while i <= 10:
    print(val*i)
    i += 1
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********
