# %% [markdown]
# <a href="https://colab.research.google.com/github/haillluuuu/CPE-009A/blob/main/Canoy_Hail_Hands_on_Activity_2_1_Literals_and_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# <center>
#
# **Technological Institute of the Philippines**<br>
# Computer Engineering Department<br>
# Quezon city Campus</center>
#
# ---
# <center><h4> Activity No. and Title: Hands-on Activity 2.1 Literals and Variables</h4></center>
#
# ---
# <center>
#
# | Course: CPE 009 | Program: BSCpE |
# |--- | --- |
# | **Course Title**: CPE 009A Object Oriented Programming | **Date Performed: 1/15/2026** |
# | **Section**: CPE12S2 | **Date Submitted:** |
# | **Student Name**: Canoy Hail B.  | **Instructor's Name: Engr. Maria Rizette H. Sayo** |
# </center>

# %% [markdown]
# **Objective/s of the activity:**
#
# 1.   Implement literals and variables in a python program.
#
# **Intended Learning Outcome:**
#
# 1.   Write a simple program implementing literals and variables.
# 2.   Use comments and identify keywords from identifiers created by users.
#
# **Discussion:**
#
# 1.   Discuss the use of variables, constants and literals in a python program.
#
# **Materials and Equipment:**
#
# 1.   List item
# 2.   List item
#
# **Procedure:**
#
# 1.   List item
# 2.   List item

# %%
# Place all the output of the procedures here

# %% [markdown]
# **Supplementary Activity**:
#
# 1.   Test 3 students from the program you created.
# 2.   The program should show the name of the student, the PRELIM, MIDTERM and FINAL grades.
# 3.   Convert the final grade into the T.I.P.s numerical grade. Please refer to the grading system.

# %% [markdown]
# **Questions**: (write your answers in blue font color and questions in black)
#
# 1.   List item
# 2.   List item

# %% [markdown]
# **Conclusion**:
# (conclusion must be based from the objective and answers whether you attained the objective/s or not and a brief explanation how you attained it)

# %% [markdown]
# Tasks: A teacher wants to calculate the final grade in a CpE course and want to write it in a python program. The following are the requirements:

# %% [markdown]
# 1.   PRELIM GRADE = 50% Prelim Exam + 50% Prelim Class Standing (CS)
# 2.   PRELIM CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
# 3.   MIDTERM GRADE = 1/3 of PRELIM GRADE + 2/3 of (50% Midterm Exam + 50% Midterm Class Standing (CS))
# 4.   MIDTERM CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
# 5.   FINAL GRADE = 1/3 of MIDTERM GRADE + 2/3 of (50% Final Exam + 50% Final Class Standing (CS))
# 6.   FINAL CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
# 7.   HOAs, Quizzes and Assignments are inputted as average of all submissions and are out of 100%.
# 8.   Major exams are inputted out of 100%.
# 9.   Show the codes that successfully run the program.
# 10.   Provide comments or documentation strings for your program.

# %%
print("- - - - - Final Grade Computer - - - - -")

#Prelim Computations
print("\n- - - - - Prelim - - - - - \n")

studentCount = 0 # Initialize studentCount before the loop
while True:
  studentCount += 1
  if studentCount > 3:
    break

  stuName = input("\n9Enter Student Name : ")
  hoa = float(input("Enter Prelim Hands-on Activity Grade : "))
  pq = float(input("Enter Prelim Quiz Grade : "))
  pag = float(input("Enter Prelim Assignment Grade : "))
  pcs = hoa*.5 + pq*.3 + pag*.2 #Computes Prelim Class Standing
  print("\nPrelim CS is: ", pcs)
  pe = float(input(("Enter Prelim Exam Grade : ")))
  pg = pe*.5 + pcs*.5 #Computes Prelim Grade

  #Midterm Computations
  print("\n- - - - -  Midterm - - - - - \n")
  mhoa = float(input("Enter Midterm Hands-on Activity Grade : "))
  mpq = float(input("Enter Midterm Quiz Grade : "))
  mag = float(input("Enter Midterm Assignment Grade : "))
  mcs = mhoa*.5 + mpq*.3 + mag*.2 #Computes Midterm Class Standing
  print("\nPrelim CS is: ", mcs)
  me = float(input(("Enter Midterm Exam Grade : ")))
  mg = (1/3 * pg) + (2/3 * (0.5 * me + 0.5 * mcs)) #Computes Midterm Grade

  #Final Computations
  print("\n- - - - - Finals - - - - - \n")
  fhoa = float(input("Enter Final Hands-on Activity Grade : "))
  fpq = float(input("Enter Final Quiz Grade : "))
  fag = float(input("Enter Final Assignment Grade : "))
  fcs = fhoa*.5 + fpq*.3 + fag*.2 #Computes Final Class Standing
  print("\nPrelim CS is: ", fcs)
  fe = float(input(("Enter Final Exam Grade : ")))
  fg = (1/3 * mg) + (2/3 * (0.5 * fe + 0.5 * fcs))

  #Final Outputs
  print("\n- - - - - Final Result - - - - - \n")
  print("\nPrelim Grade is: ", "%.2f" % pg)
  print("\nMidterm Grade is: ", "%.2f" % mg)
  print("\nFinal Grade is: ", "%.2f" % fg)

  if fg >= 75:
    print("Passed")
  if fg >= 90:
    print("Honor Student")
  elif fg >= 95:
    print("With Heighest Honors")
  else:
    print("Failed")
# Out:
# - - - - - Final Grade Computer - - - - -
#
# - - - - - Prelim - - - - -
#
#
# Enter Student Name : Hail
# Enter Prelim Hands-on Activity Grade : 90
# Enter Prelim Quiz Grade : 90
# Enter Prelim Assignment Grade : 89
#
# Prelim CS is:  89.8
# Enter Prelim Exam Grade : 98
#
# - - - - -  Midterm - - - - -
#
# Enter Midterm Hands-on Activity Grade : 98
# Enter Midterm Quiz Grade : 89
# Enter Midterm Assignment Grade : 89
#
# Prelim CS is:  93.5
# Enter Midterm Exam Grade : 89
#
# - - - - - Finals - - - - -
#
# Enter Final Hands-on Activity Grade : 89
# Enter Final Quiz Grade : 98
# Enter Final Assignment Grade : 89
#
# Prelim CS is:  91.7
# Enter Final Exam Grade : 90
#
# - - - - - Final Result - - - - -
#
#
# Prelim Grade is:  93.90
#
# Midterm Grade is:  92.13
#
# Final Grade is:  91.28
# Passed
# Honor Student
#
# Enter Student Name : Jenny
# Enter Prelim Hands-on Activity Grade : 99
# Enter Prelim Quiz Grade : 99
# Enter Prelim Assignment Grade : 98
#
# ...
