# %% [markdown]
# <a href="https://colab.research.google.com/github/haillluuuu/CPE-009A/blob/main/gawa_ni_canoy_hail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hands-on Activity 3.1

# %% [markdown]
# Name: Canoy, Hail B.
#
# Section: CPE12S2
#
# Date performed: Febuary 6, 2026

# %% [markdown]
# Lists
# 1. Create a variable numberlist and assign it the value of [5,4,2,1,3].
# 2. Print the following values below:

# %%
#a. len(numberlist)

numberlist = [5, 4, 2, 1, 3]
print(len(numberlist))
# Out:
# 5

# %%
#b. numberlist[0]

print(numberlist[0])
# Out:
# 5

# %%
#c. numberlist[1]

print(numberlist[1])
# Out:
# 4

# %%
#d. numberlist[2]

print(numberlist[2])
# Out:
# 2

# %%
#e. numberlist[3]

print(numberlist[3])
# Out:
# 1

# %%
#f. numberlist[4]

print(numberlist[4])
# Out:
# 3

# %%
#g. numberlist[5]

print(numberlist[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-362/1707572209.py in <cell line: 0>()
#       1 #g. numberlist[5]
#       2
# ----> 3 print(numberlist[5])
#
# IndexError: list index out of range

# %%
#h. numberlist[-1]

print(numberlist[-1])
# Out:
# 3

# %%
#i. numberlist[-2]

print(numberlist[-2])
# Out:
# 1

# %%
#j. numberlist[-3]

print(numberlist[-3])
# Out:
# 2

# %%
#k. numberlist[-4]

print(numberlist[-4])

# %%
#l. numberlist[-5]

print(numberlist[-5])
# Out:
# 5

# %%
#m. numberlist[-6]

print(numberlist[-6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-362/4203008533.py in <cell line: 0>()
#       1 #m. numberlist[-6]
#       2
# ----> 3 print(numberlist[-6])
#
# IndexError: list index out of range

# %% [markdown]
# Reminder: Use the print() command. The values numberlist[5] and numberlist[-6] should return an error. 3. Write your observation after printing all the values.
#
# 4. Create a variable named itemlist and assign it the value of [1,-2.0,[1,2,3],”Word”]
#
# 5. Print the following values below:

# %%
itemlist = [1, -2.0, [1, 2, 3], "Word"]

#a. len(itemlist)

print(len(itemlist))
# Out:
# 4

# %%
#b. itemlist [0]

print(itemlist[0])
# Out:
# 1

# %%
#c. itemlist [1]

print(itemlist[1])
# Out:
# -2.0

# %%
#d. itemlist [2]

print(itemlist[2])
# Out:
# [1, 2, 3]

# %%
#e. itemlist [3]

print(itemlist[3])
# Out:
# Word

# %%
#f. len(itemlist[2])

print(len(itemlist[2]))
# Out:
# 3

# %%
#g. itemlist [2][0]

print(itemlist[2][0])
# Out:
# 1

# %%
#h. itemlist [2][1]

print(itemlist[2][1])
# Out:
# 2

# %%
#i. itemlist [2][2]

print(itemlist[2][2])
# Out:
# 3

# %%
#j. itemlist [-1]

print(itemlist[-1])
# Out:
# Word

# %%
#k. itemlist [-2]

print(itemlist[-2])
# Out:
# [1, 2, 3]

# %%
#l. itemlist [-3]

print(itemlist[-3])
# Out:
# -2.0

# %%
#m. itemlist [-4]

print(itemlist[-4])
# Out:
# 1

# %%
#n. len(itemlist[-2])

print(len(itemlist[-2]))
# Out:
# 3

# %%
#o. itemlist[-2][0]

print(itemlist[-2][0])
# Out:
# 1

# %%
#p. itemlist[-2][1]

print(itemlist[-2][1])
# Out:
# 2

# %%
#q. itemlist[-2][2]

print(itemlist[-2][2])
# Out:
# 3

# %%
#r. itemlist[-2][-3]

print(itemlist[-2][-3])
# Out:
# 1

# %%
#s. itemlist[-2][-2]

print(itemlist[-2][-2])
# Out:
# 2

# %%
#t. itemlist[-2][-1]

print(itemlist[-2][-1])
# Out:
# 3

# %% [markdown]
# Index Slicing
#
# 1. Create a new variable longlist and assign it the value of numberlist + itemlist.
#
# 2. Print the following values below and write your observation for each of the following sub-groups (sub-headings): a. len(longlist)

# %%
longlist = numberlist + itemlist

#a. len(longlist)

print(len(longlist))
# Out:
# 9

# %%
#b. longlist [:]

print(longlist[:])

# %%
#c. longlist[:9]

print(longlist[:9])

# %%
#d. longlist[0:]

print(longlist[0:])

# %%
#e. longlist[1:]

print(longlist[1:])

# %%
#f. longlist[2:]

print(longlist[2:])
# Out:
# [2, 1, 3, 1, -2.0, [1, 2, 3], 'Word']

# %% [markdown]
# Index Slicing with Range

# %%
#g. longlist[2:5]

print(longlist[2:5])
# Out:
# [2, 1, 3]

# %%
#h. longlist[5:2]

print(longlist[5:2])
# Out:
# []

# %%
#i. longlist[8:]

print(longlist[8:])
# Out:
# ['Word']

# %%
#j. longlist[9:]

# %% [markdown]
# Index Slicing using Negative Indices

# %%
#k. longlist[-9:]

# %%
#l. longlist[-8:]

# %%
#m. longlist[-8:-7]

# %%
#n. longlist[-1:]

# %% [markdown]
# Other properties of Index Slicing

# %%
#o. longlist[10:20]

# %%
#p. longlist[-7:5]

# %% [markdown]
# Index Slicing with Step parameter

# %%
#q. longlist[::1]

# %%
#r. longlist[::2]

# %%
#s. longlist[1:8:2]

# %%
#t. longlist[9:1:-1]

# %%
#u. longlist[-1::1]

# %%
#v. longlist[-1::-1]
